# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
import scipy
from scipy import stats
# %matplotlib inline

# %%
#import the data set

mtcars_data = pd.read_csv('mtcars_data.csv')

# %%
#prints the data set

print(mtcars_data)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#getting samples of the data set - Prints first 4 rows

mtcars_data.head(4)
# Out:
#             model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0       Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1   Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2      Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3  Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1

# %%
#getting samples of the data set - Print from row 7 to row 20

mtcars_data[7:20]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# ...

# %%
#getting samples of the data set - Prints last 7 rows

mtcars_data.tail(7)
# Out:
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 25       Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.9   1   1     4
# 26   Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.7   0   1     5
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 25     1
# 26     2
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %%
#getting samples of the data set - Prints first 10 rows of the model names and the cyl dimension

mtcars_data[{'model','cyl'}][0:10]
# Out:
#    cyl              model
# 0    6          Mazda RX4
# 1    6      Mazda RX4 Wag
# 2    4         Datsun 710
# 3    6     Hornet 4 Drive
# 4    8  Hornet Sportabout
# 5    6            Valiant
# 6    8         Duster 360
# 7    4          Merc 240D
# 8    4           Merc 230
# 9    6           Merc 280

# %%
mtcars_data.dtypes
# Out:
# model     object
# mpg      float64
# cyl        int64
# disp     float64
# hp         int64
# drat     float64
# wt       float64
# qsec     float64
# vs         int64
# am         int64
# gear       int64
# carb       int64
# dtype: object

# %%
#prints the column names of the data set
mtcars_data.columns
# Out:
# Index(['model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am',
#        'gear', 'carb'],
#       dtype='object')

# %%
mtcars_categorical_variables = mtcars_data.select_dtypes(include=['object','int64'])

# %%
#prints only the object and the integer attributes

mtcars_categorical_variables
# Out:
#                   model  cyl   hp  vs  am  gear  carb
# 0             Mazda RX4    6  110   0   1     4     4
# 1         Mazda RX4 Wag    6  110   0   1     4     4
# 2            Datsun 710    4   93   1   1     4     1
# 3        Hornet 4 Drive    6  110   1   0     3     1
# 4     Hornet Sportabout    8  175   0   0     3     2
# 5               Valiant    6  105   1   0     3     1
# 6            Duster 360    8  245   0   0     3     4
# 7             Merc 240D    4   62   1   0     4     2
# 8              Merc 230    4   95   1   0     4     2
# 9              Merc 280    6  123   1   0     4     4
# 10            Merc 280C    6  123   1   0     4     4
# 11           Merc 450SE    8  180   0   0     3     3
# 12           Merc 450SL    8  180   0   0     3     3
# 13          Merc 450SLC    8  180   0   0     3     3
# 14   Cadillac Fleetwood    8  205   0   0     3     4
# 15  Lincoln Continental    8  215   0   0     3     4
# ...

# %%
mtcars_quantitative_variables = mtcars_data.select_dtypes(include=['object','float64'])

# %%
#prints only the object and the float attribute

mtcars_quantitative_variables
# Out:
#                   model   mpg   disp  drat     wt   qsec
# 0             Mazda RX4  21.0  160.0  3.90  2.620  16.46
# 1         Mazda RX4 Wag  21.0  160.0  3.90  2.875  17.02
# 2            Datsun 710  22.8  108.0  3.85  2.320  18.61
# 3        Hornet 4 Drive  21.4  258.0  3.08  3.215  19.44
# 4     Hornet Sportabout  18.7  360.0  3.15  3.440  17.02
# 5               Valiant  18.1  225.0  2.76  3.460  20.22
# 6            Duster 360  14.3  360.0  3.21  3.570  15.84
# 7             Merc 240D  24.4  146.7  3.69  3.190  20.00
# 8              Merc 230  22.8  140.8  3.92  3.150  22.90
# 9              Merc 280  19.2  167.6  3.92  3.440  18.30
# 10            Merc 280C  17.8  167.6  3.92  3.440  18.90
# 11           Merc 450SE  16.4  275.8  3.07  4.070  17.40
# 12           Merc 450SL  17.3  275.8  3.07  3.730  17.60
# 13          Merc 450SLC  15.2  275.8  3.07  3.780  18.00
# 14   Cadillac Fleetwood  10.4  472.0  2.93  5.250  17.98
# ...

# %%
#give the mean, minimum, count and maximum value of the 'cyl' attribute

mtcars_categorical_variables.cyl.agg(['min','max','count','mean'])
# Out:
# min       4.0000
# max       8.0000
# count    32.0000
# mean      6.1875
# Name: cyl, dtype: float64

# %%
#give the mean, minimum, count and maximum value of the 'hp' attribute

mtcars_categorical_variables.hp.agg(['min','max','count','mean'])
# Out:
# min       52.0000
# max      335.0000
# count     32.0000
# mean     146.6875
# Name: hp, dtype: float64

# %%
#give the mean, minimum, count and maximum values of all the attribute with integers from the data set
mtcars_agg_int = mtcars_categorical_variables.agg(['min','max','count','mean'])

# %%
mtcars_agg_int
# Out:
#              model      cyl        hp       vs        am     gear     carb
# min    AMC Javelin   4.0000   52.0000   0.0000   0.00000   3.0000   1.0000
# max     Volvo 142E   8.0000  335.0000   1.0000   1.00000   5.0000   8.0000
# count           32  32.0000   32.0000  32.0000  32.00000  32.0000  32.0000
# mean           NaN   6.1875  146.6875   0.4375   0.40625   3.6875   2.8125

# %%
mtcars_agg_int.drop('model', axis = 1,inplace = True)

# %%
mtcars_agg_int
# Out:
#            cyl        hp       vs        am     gear     carb
# min     4.0000   52.0000   0.0000   0.00000   3.0000   1.0000
# max     8.0000  335.0000   1.0000   1.00000   5.0000   8.0000
# count  32.0000   32.0000  32.0000  32.00000  32.0000  32.0000
# mean    6.1875  146.6875   0.4375   0.40625   3.6875   2.8125

# %%
#gives count of the "cyl" attribute
mtcars_categorical_variables.cyl.value_counts()
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
#another method to give counts of the "cyl" attribute
cyl_counts=mtcars_categorical_variables.groupby(["cyl"]).size().reset_index(name='count')

# %%
cyl_counts
# Out:
#    cyl  count
# 0    4     11
# 1    6      7
# 2    8     14

# %%
sns.countplot(x='cyl', data = mtcars_categorical_variables)

# %%
hp_counts=mtcars_categorical_variables.groupby(["hp"]).size().reset_index(name='count')

# %%
hp_counts
# Out:
#      hp  count
# 0    52      1
# 1    62      1
# 2    65      1
# 3    66      2
# 4    91      1
# 5    93      1
# 6    95      1
# 7    97      1
# 8   105      1
# 9   109      1
# 10  110      3
# 11  113      1
# 12  123      2
# 13  150      2
# 14  175      3
# 15  180      3
# 16  205      1
# 17  215      1
# 18  230      1
# 19  245      2
# 20  264      1
# 21  335      1

# %%
vs_counts=mtcars_categorical_variables.groupby(["vs"]).size().reset_index(name='count')

# %%
vs_counts
# Out:
#    vs  count
# 0   0     18
# 1   1     14

# %%
sns.countplot(x = 'vs', data = mtcars_categorical_variables)

# %%
am_counts = mtcars_categorical_variables.groupby('am').size().reset_index(name='count')

# %%
am_counts
# Out:
#    am  count
# 0   0     19
# 1   1     13

# %%
sns.countplot(x = 'am', data = mtcars_categorical_variables)

# %%
gear_counts = mtcars_categorical_variables.groupby('gear').size().reset_index(name='count')

# %%
gear_counts
# Out:
#    gear  count
# 0     3     15
# 1     4     12
# 2     5      5

# %%
sns.countplot(x = 'gear', data = mtcars_categorical_variables)

# %%
carb_counts = mtcars_categorical_variables.groupby('carb').size().reset_index(name='count')

# %%
carb_counts
# Out:
#    carb  count
# 0     1      7
# 1     2     10
# 2     3      3
# 3     4     10
# 4     6      1
# 5     8      1

# %%
mtcars_quantitative_variables
# Out:
#                   model   mpg   disp  drat     wt   qsec
# 0             Mazda RX4  21.0  160.0  3.90  2.620  16.46
# 1         Mazda RX4 Wag  21.0  160.0  3.90  2.875  17.02
# 2            Datsun 710  22.8  108.0  3.85  2.320  18.61
# 3        Hornet 4 Drive  21.4  258.0  3.08  3.215  19.44
# 4     Hornet Sportabout  18.7  360.0  3.15  3.440  17.02
# 5               Valiant  18.1  225.0  2.76  3.460  20.22
# 6            Duster 360  14.3  360.0  3.21  3.570  15.84
# 7             Merc 240D  24.4  146.7  3.69  3.190  20.00
# 8              Merc 230  22.8  140.8  3.92  3.150  22.90
# 9              Merc 280  19.2  167.6  3.92  3.440  18.30
# 10            Merc 280C  17.8  167.6  3.92  3.440  18.90
# 11           Merc 450SE  16.4  275.8  3.07  4.070  17.40
# 12           Merc 450SL  17.3  275.8  3.07  3.730  17.60
# 13          Merc 450SLC  15.2  275.8  3.07  3.780  18.00
# 14   Cadillac Fleetwood  10.4  472.0  2.93  5.250  17.98
# ...

# %%
#give the mean, minimum, count and maximum values of all the attribute with float values from the data set

mtcars_agg_float = mtcars_quantitative_variables.agg(['min','max','median'])

# %%
mtcars_agg_float
# Out:
#               model   mpg   disp   drat     wt   qsec
# min     AMC Javelin  10.4   71.1  2.760  1.513  14.50
# max      Volvo 142E  33.9  472.0  4.930  5.424  22.90
# median          NaN  19.2  196.3  3.695  3.325  17.71

# %%
mtcars_agg_float.drop('model',axis=1, inplace = True )

# %%
mtcars_agg_float
# Out:
#          mpg   disp   drat     wt   qsec
# min     10.4   71.1  2.760  1.513  14.50
# max     33.9  472.0  4.930  5.424  22.90
# median  19.2  196.3  3.695  3.325  17.71

# %%
mtcars_quantitative_variables.max()
# Out:
# model    Volvo 142E
# mpg            33.9
# disp            472
# drat           4.93
# wt            5.424
# qsec           22.9
# dtype: object

# %%
mtcars_quantitative_variables.sum()
# Out:
# model    Mazda RX4Mazda RX4 WagDatsun 710Hornet 4 Drive...
# mpg                                                  642.9
# disp                                                7383.1
# drat                                                115.09
# wt                                                 102.952
# qsec                                                571.16
# dtype: object

# %%
wt=mtcars_quantitative_variables.wt

# %%
#prints the row number that has the highest value from the "wt" attribute
wt.idxmax()
# Out:
# 15

# %%
mtcars_quantitative_variables.describe()
# Out:
#              mpg        disp       drat         wt       qsec
# count  32.000000   32.000000  32.000000  32.000000  32.000000
# mean   20.090625  230.721875   3.596563   3.217250  17.848750
# std     6.026948  123.938694   0.534679   0.978457   1.786943
# min    10.400000   71.100000   2.760000   1.513000  14.500000
# 25%    15.425000  120.825000   3.080000   2.581250  16.892500
# 50%    19.200000  196.300000   3.695000   3.325000  17.710000
# 75%    22.800000  326.000000   3.920000   3.610000  18.900000
# max    33.900000  472.000000   4.930000   5.424000  22.900000

# %%
mtcars_categorical_variables.describe()
# Out:
#              cyl          hp         vs         am       gear     carb
# count  32.000000   32.000000  32.000000  32.000000  32.000000  32.0000
# mean    6.187500  146.687500   0.437500   0.406250   3.687500   2.8125
# std     1.785922   68.562868   0.504016   0.498991   0.737804   1.6152
# min     4.000000   52.000000   0.000000   0.000000   3.000000   1.0000
# 25%     4.000000   96.500000   0.000000   0.000000   3.000000   2.0000
# 50%     6.000000  123.000000   0.000000   0.000000   4.000000   2.0000
# 75%     8.000000  180.000000   1.000000   1.000000   4.000000   4.0000
# max     8.000000  335.000000   1.000000   1.000000   5.000000   8.0000

# %%
#bivariate analysis for categorical attributes

sns.countplot(x='gear', hue='vs', data=mtcars_categorical_variables,palette='rainbow')

# %%
sns.violinplot(mtcars_categorical_variables.vs, mtcars_categorical_variables.gear)

# %%
sns.countplot(x='cyl', hue='vs', data=mtcars_categorical_variables,palette='rainbow')

# %%
sns.countplot(x='am', hue='vs', data=mtcars_categorical_variables,palette='rainbow')

# %%
sns.violinplot(mtcars_categorical_variables.vs, mtcars_categorical_variables.am)

# %%
sns.countplot(x='carb', hue='vs', data=mtcars_categorical_variables,palette='rainbow')

# %%
sns.violinplot(mtcars_categorical_variables.vs, mtcars_categorical_variables.carb)
